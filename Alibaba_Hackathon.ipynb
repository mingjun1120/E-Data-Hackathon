# %%
# Initialize our notebook / environment

# matplotlib is the plotting engine / library, we tell the notebook we want our chart to be displayed inline
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
sns.set()
# df = pd.read_csv("Annual_active_consumers.csv")
df = pd.read_excel (r'C:\Users\Admin\Jupyter Projects\alibaba_combine.xlsx')
print (df)
df.head(10)
# Out:
#     Revenue (in RMB millions)  Number of annual active consumers (millions)  \
# 0                       15532                                           350
# 1                       18538                                           367
# 2                       20231                                           386
# 3                       32111                                           407
# 4                       21455                                           423
# 5                       27241                                           434
# 6                       28493                                           439
# 7                       46576                                           443
# 8                       31570                                           454
# 9                       43027                                           466
# 10                      46462                                           488
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 4 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Revenue (in RMB millions)                        22 non-null     int64
#  1   Number of annual active consumers (millions)     22 non-null     int64
#  2   Number of mobile monthly active user (millions)  22 non-null     int64
#  3   Year (Quarterly)                                 22 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 832.0 bytes

# %%
# Before remove null values
df.shape
# Out:
# (22, 4)

# %%
# Check missing values
df.isnull().sum()
# Out:
# Revenue (in RMB millions)                          0
# Number of annual active consumers (millions)       0
# Number of mobile monthly active user (millions)    0
# Year (Quarterly)                                   0
# dtype: int64

# %%
# Check variable correlation
df.corr()
# Out:
#                                                  Revenue (in RMB millions)  \
# Revenue (in RMB millions)                                         1.000000
# Number of annual active consumers (millions)                      0.948327
# Number of mobile monthly active user (millions)                   0.942405
#
#                                                  Number of annual active consumers (millions)  \
# Revenue (in RMB millions)                                                            0.948327
# Number of annual active consumers (millions)                                         1.000000
# Number of mobile monthly active user (millions)                                      0.990287
#
#                                                  Number of mobile monthly active user (millions)
# Revenue (in RMB millions)                                                               0.942405
# Number of annual active consumers (millions)                                            0.990287
# ...

# %%
sns.set(rc={'figure.figsize':(6,5)})
sns.set_context("talk", font_scale=1)

#sns = seaborn    
#corr = correlation
#annot = annotation
sns.heatmap(df.corr(), cmap='Reds', annot=True, fmt=".2f")
